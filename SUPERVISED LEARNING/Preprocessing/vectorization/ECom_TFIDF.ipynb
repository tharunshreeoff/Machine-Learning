# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv(
    "C:\\Users\\Admin\\OneDrive\\Desktop\\data science\\ML\\SUPERVISED LEARNING\\Dataset\\ecommerceDataset.csv",
    header=None,
    names=["Category", "Description"]
)

df.head()
# Out:
#     Category                                        Description
# 0  Household  Paper Plane Design Framed Wall Hanging Motivat...
# 1  Household  SAF 'Floral' Framed Painting (Wood, 30 inch x ...
# 2  Household  SAF 'UV Textured Modern Art Print Framed' Pain...
# 3  Household  SAF Flower Print Framed Painting (Synthetic, 1...
# 4  Household  Incredible Gifts India Wooden Happy Birthday U...

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 50424 entries, 0 to 50424
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Category     50424 non-null  str
#  1   Description  50424 non-null  str
# dtypes: str(2)
# memory usage: 1.2 MB

# %%
X = df.Category
y = df.Description

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X,y,random_state=42,train_size=0.8)

# %%
main_pipe = Pipeline(
    steps=[
        ('vector',TfidfVectorizer()),
        ('model',LogisticRegression())
    ]
)
main_pipe.fit(xtrain,ytrain)
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:1201: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   check_classification_targets(y)
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[6], line 7
#       1 main_pipe = Pipeline(
#       2     steps=[
#       3         ('vector',TfidfVectorizer()),
#       4         ('model',LogisticRegression())
#       5     ]
#       6 )
# ----> 7 main_pipe.fit(xtrain,ytrain)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\pipeline.py:621, in Pipeline.fit(self, X, y, **params)
#     615     if self._final_estimator != "passthrough":
#     616         last_step_params = self._get_metadata_for_step(
#     617             step_idx=len(self) - 1,
#     618             step_params=routed_params[self.steps[-1][0]],
#     619             all_params=params,
#     620         )
# --> 621         self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     623 return self
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:1262, in LogisticRegression.fit(self, X, y, sample_weight)
#    1258 # TODO: enable multi-threading if benchmarks show a positive effect,
#    1259 # see https://github.com/scikit-learn/scikit-learn/issues/32162
#    1260 n_threads = 1
# -> 1262 coefs, _, n_iter = _logistic_regression_path(
#    1263     X,
#    1264     y,
#    1265     classes=self.classes_,
#    1266     Cs=[C_],
#    1267     l1_ratio=self.l1_ratio,
#    1268     fit_intercept=self.fit_intercept,
#    1269     tol=self.tol,
#    1270     verbose=self.verbose,
#    1271     solver=solver,
#    1272     max_iter=self.max_iter,
#    1273     class_weight=self.class_weight,
#    1274     check_input=False,
#    1275     random_state=self.random_state,
#    1276     coef=warm_start_coef,
#    1277     penalty=penalty,
#    1278     max_squared_sum=max_squared_sum,
#    1279     sample_weight=sample_weight,
#    1280     n_threads=n_threads,
#    1281 )
#    1283 self.n_iter_ = np.asarray(n_iter, dtype=np.int32)
#    1285 self.coef_ = coefs[0]
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:392, in _logistic_regression_path(X, y, classes, Cs, fit_intercept, max_iter, tol, verbose, solver, coef, class_weight, dual, penalty, intercept_scaling, random_state, check_input, max_squared_sum, sample_weight, l1_ratio, n_threads)
#     388 l2_reg_strength = 1.0 / (C * sw_sum)
#     389 iprint = [-1, 50, 1, 100, 101][
#     390     np.searchsorted(np.array([0, 1, 2, 3]), verbose)
#     391 ]
# --> 392 opt_res = optimize.minimize(
#     393     func,
#     394     w0,
#     395     method="L-BFGS-B",
#     396     jac=True,
#     397     args=(X, target, sample_weight, l2_reg_strength, n_threads),
#     398     options={
#     399         "maxiter": max_iter,
#     400         "maxls": 50,  # default is 20
#     401         "gtol": tol,
#     402         "ftol": 64 * np.finfo(float).eps,
#     403         **_get_additional_lbfgs_options_dict("iprint", iprint),
#     404     },
#     405 )
#     406 n_iter_i = _check_optimize_result(
#     407     solver,
#     408     opt_res,
#     409     max_iter,
#     410     extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
#     411 )
#     412 w0, loss = opt_res.x, opt_res.fun
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\scipy\optimize\_minimize.py:784, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     781     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     782                              **options)
#     783 elif meth == 'l-bfgs-b':
# --> 784     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     785                            callback=callback, **options)
#     786 elif meth == 'tnc':
#     787     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     788                         **options)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\scipy\optimize\_lbfgsb_py.py:413, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, workers, **unknown_options)
#     410     x0 = np.clip(x0, bounds[0], bounds[1])
#     412 # _prepare_scalar_function can use bounds=None to represent no bounds
# --> 413 sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#     414                               bounds=bounds,
#     415                               finite_diff_rel_step=finite_diff_rel_step,
#     416                               workers=workers)
#     418 func_and_grad = sf.fun_and_grad
#     420 nbd = zeros(n, np.int32)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\scipy\optimize\_optimize.py:310, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess, workers)
#     306 workers = workers or map
#     308 # ScalarFunction caches. Reuse of fun(x) during grad
#     309 # calculation reduces overall function evaluations.
# --> 310 sf = ScalarFunction(fun, x0, args, grad, hess,
#     311                     finite_diff_rel_step, bounds, epsilon=epsilon,
#     312                     workers=workers)
#     314 return sf
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\scipy\optimize\_differentiable_functions.py:283, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon, workers)
#     281 # Initial function evaluation
#     282 self._nfev = 0
# --> 283 self._update_fun()
#     285 # Initial gradient evaluation
#     286 self._wrapped_grad = _ScalarGradWrapper(
#     287     grad,
#     288     fun=self._wrapped_fun,
#     289     args=args,
#     290     finite_diff_options=finite_diff_options,
#     291 )
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\scipy\optimize\_differentiable_functions.py:362, in ScalarFunction._update_fun(self)
#     360 def _update_fun(self):
#     361     if not self.f_updated:
# --> 362         fx = self._wrapped_fun(self.x)
#     363         self._nfev += 1
#     364         if fx < self._lowest_f:
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\scipy\_lib\_util.py:603, in _ScalarFunctionWrapper.__call__(self, x)
#     600 def __call__(self, x):
#     601     # Send a copy because the user may overwrite it.
#     602     # The user of this class might want `x` to remain unchanged.
# --> 603     fx = self.f(np.copy(x), *self.args)
#     604     self.nfev += 1
#     606     # Make sure the function returns a true scalar
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\scipy\optimize\_optimize.py:80, in MemoizeJac.__call__(self, x, *args)
#      78 def __call__(self, x, *args):
#      79     """ returns the function value """
# ---> 80     self._compute_if_needed(x, *args)
#      81     return self._value
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\scipy\optimize\_optimize.py:74, in MemoizeJac._compute_if_needed(self, x, *args)
#      72 if not np.all(x == self.x) or self._value is None or self.jac is None:
#      73     self.x = np.asarray(x).copy()
# ---> 74     fg = self.fun(x, *args)
#      75     self.jac = fg[1]
#      76     self._value = fg[0]
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_linear_loss.py:315, in LinearModelLoss.loss_gradient(self, coef, X, y, sample_weight, l2_reg_strength, n_threads, raw_prediction)
#     312 n_dof = n_features + int(self.fit_intercept)
#     314 if raw_prediction is None:
# --> 315     weights, intercept, raw_prediction = self.weight_intercept_raw(coef, X)
#     316 else:
#     317     weights, intercept = self.weight_intercept(coef)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_linear_loss.py:206, in LinearModelLoss.weight_intercept_raw(self, coef, X)
#     203     raw_prediction = X @ weights + intercept
#     204 else:
#     205     # weights has shape (n_classes, n_dof)
# --> 206     raw_prediction = X @ weights.T + intercept  # ndarray, likely C-contiguous
#     208 return weights, intercept, raw_prediction
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\scipy\sparse\_base.py:923, in _spbase.__matmul__(self, other)
#     920 if isscalarlike(other):
#     921     raise ValueError("Scalar operands are not allowed, "
#     922                      "use '*' instead")
# --> 923 return self._matmul_dispatch(other)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\scipy\sparse\_base.py:815, in _spbase._matmul_dispatch(self, other)
#     813         return result.reshape(M, 1)
#     814     elif other.ndim == 2 and other.shape[0] == N:
# --> 815         return self._matmul_multivector(other)
#     817 if isscalarlike(other):
#     818     # scalar value
#     819     return self._mul_scalar(other)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python314\Lib\site-packages\scipy\sparse\_compressed.py:403, in _cs_matrix._matmul_multivector(self, other)
#     400 M, N = self._shape_as_2d
#     401 n_vecs = other.shape[-1]  # number of column vectors
# --> 403 result = np.zeros((M, n_vecs),
#     404                   dtype=upcast_char(self.dtype.char, other.dtype.char))
#     406 # csr_matvecs or csc_matvecs
#     407 fn = getattr(_sparsetools, self.format + '_matvecs')
#
# MemoryError: Unable to allocate 7.39 GiB for an array with shape (40339, 24602) and data type float64
