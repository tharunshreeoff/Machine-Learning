# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

# %%
df = pd.read_csv('C:\\Users\\Admin\\OneDrive\\Desktop\\data science\\ML\\SUPERVISED LEARNING\\Dataset\\standardscaler.csv')

# %%
df.corr()
# Out:
#           Feature1  Feature2  Feature3    Target
# Feature1  1.000000 -0.022619 -0.039036 -0.037666
# Feature2 -0.022619  1.000000 -0.024157 -0.024257
# Feature3 -0.039036 -0.024157  1.000000  0.995135
# Target   -0.037666 -0.024257  0.995135  1.000000

# %%
X = df.drop(columns='Target')
y = df['Target']

# %%
xtrain, xtest, ytrain, ytest = train_test_split(X,y,train_size=0.8,random_state=42)

# %%
scaling = StandardScaler()
xtrain_scaled = scaling.fit_transform(xtrain)
xtest_scaled = scaling.transform(xtest)

# %%
round(np.mean(xtrain_scaled[:,0]))

# %%
np.std(xtrain_scaled[:,0])
