# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
s_df = pd.read_csv('C:\\Users\\Admin\\OneDrive\\Desktop\\data science\\ML\\SUPERVISED LEARNING\\Dataset\\Salary_dataset.csv')
i_df = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Desktop\\data science\\ML\\SUPERVISED LEARNING\\Dataset\\Ice Cream Sales - temperatures.csv")

# %%
s_df.corr()
# Out:
#                  Unnamed: 0  YearsExperience    Salary
# Unnamed: 0         1.000000         0.986460  0.960826
# YearsExperience    0.986460         1.000000  0.978242
# Salary             0.960826         0.978242  1.000000

# %%
plt.scatter(s_df['YearsExperience'], s_df['Salary'])
plt.show()

# %% [markdown]
# **Observation**
#
# Strongly correlation between years_of_experience and salary

# %%
i_df.corr()
# Out:
#                    Temperature  Ice Cream Profits
# Temperature           1.000000           0.988446
# Ice Cream Profits     0.988446           1.000000

# %%
plt.scatter(i_df['Temperature'], i_df['Ice Cream Profits'])
plt.show()

# %% [markdown]
# **Observation**
#
# Strongly correlation between temparature and profits columns
