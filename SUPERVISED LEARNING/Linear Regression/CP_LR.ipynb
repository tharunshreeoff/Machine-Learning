# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, r2_score
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:\\Users\\Admin\\OneDrive\\Desktop\\data science\\ML\\SUPERVISED LEARNING\\Dataset\\CarPrice_Assignment.csv')

'''categorical columns'''
df.drop(columns=['car_ID', 'symboling','CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody',
       'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber','fuelsystem',], inplace=True)

# %%
df.columns
# Out:
# Index(['wheelbase', 'carlength', 'carwidth', 'carheight', 'curbweight',
#        'enginesize', 'boreratio', 'stroke', 'compressionratio', 'horsepower',
#        'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='str')

# %%
df.corr()
# Out:
#                   wheelbase  carlength  carwidth  carheight  curbweight  \
# wheelbase          1.000000   0.874587  0.795144   0.589435    0.776386
# carlength          0.874587   1.000000  0.841118   0.491029    0.877728
# carwidth           0.795144   0.841118  1.000000   0.279210    0.867032
# carheight          0.589435   0.491029  0.279210   1.000000    0.295572
# curbweight         0.776386   0.877728  0.867032   0.295572    1.000000
# enginesize         0.569329   0.683360  0.735433   0.067149    0.850594
# boreratio          0.488750   0.606454  0.559150   0.171071    0.648480
# stroke             0.160959   0.129533  0.182942  -0.055307    0.168790
# compressionratio   0.249786   0.158414  0.181129   0.261214    0.151362
# horsepower         0.353294   0.552623  0.640732  -0.108802    0.750739
# peakrpm           -0.360469  -0.287242 -0.220012  -0.320411   -0.266243
# citympg           -0.470414  -0.670909 -0.642704  -0.048640   -0.757414
# ...

# %% [markdown]
# curbweight, enginesize, horsepower those three columns are strongly correlated
#
# so the model learns is good

# %%
X = df.drop(columns=['price'])
y = df['price']

xtrain, xtest, ytrain, ytest = train_test_split(X, y, train_size=0.8, random_state=42)

# %%
model = LinearRegression()

# %%
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
ytrain_pred = model.predict(xtrain)
ytest_pred = model.predict(xtest)

# %%
train_score = model.score(xtrain, ytrain)
test_score = model.score(xtest, ytest)

print(f"Train Score : {train_score} \nTest Score : {test_score}")
# Out:
# Train Score : 0.8572740580217961
# Test Score : 0.8146957315667042

# %%
mean_absolute_error(ytrain, ytrain_pred)
# Out:
# 2195.5307087193537

# %%
root_mean_squared_error(ytrain, ytrain_pred)
# Out:
# 2917.5103287667303

# %%
sns.scatterplot(x=ytrain, y=ytrain_pred,color='purple')
sns.scatterplot(x=ytest, y=ytest_pred,color='red')

plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual vs Predicted Price ')
plt.show()
